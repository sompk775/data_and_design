# %% [markdown]
# # Homework #1

# %% [markdown]
# The dataset I chose was titled "The Ultimate Halloween Candy Power Ranking" from Kaggle. I chose it because I was inspired by the ramen dataset we looked at in class, I thought the original dataset I had picked wasn't as interesting even though it was important. I also picked this particular dataset because I am very excited for Halloween. People buy lots of candy for Halloween, but I never really thought about their ranking because as a child it was more about quantity over quality, and I would always have my own personal favorites. The dataset obtained it's information from a website where they were shown two candies and asked to click on which candy they prefer. They also had over eight thousand participants.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('data/candy-data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 13 columns):
# competitorname      85 non-null object
# chocolate           85 non-null int64
# fruity              85 non-null int64
# caramel             85 non-null int64
# peanutyalmondy      85 non-null int64
# nougat              85 non-null int64
# crispedricewafer    85 non-null int64
# hard                85 non-null int64
# bar                 85 non-null int64
# pluribus            85 non-null int64
# sugarpercent        85 non-null float64
# pricepercent        85 non-null float64
# winpercent          85 non-null float64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 8.7+ KB

# %% [markdown]
# According to the dataset, they were looking at 13 different variables. They used 85 different brands of candy.
# #pluribus = if it came in a bag or box
#
# Only one of the variables is an object. There are nine variables which are integers, and that is because they coded them in binary with 1 = yes, 0 = no. The last  three float64 are numbers with decimals because they were taken from percentiles so they won't always be a whole number. Because the dataset already came coded in binary format, I don't think there is anything I need to recode for now or that there is anything missing.

# %%
df.head()
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %%
df.groupby('competitorname').sum()
# Out:
#                              chocolate  fruity  caramel  peanutyalmondy  \
# competitorname
# 100 Grand                            1       0        1               0
# 3 Musketeers                         1       0        0               0
# Air Heads                            0       1        0               0
# Almond Joy                           1       0        0               1
# Baby Ruth                            1       0        1               1
# Boston Baked Beans                   0       0        0               1
# Candy Corn                           0       0        0               0
# Caramel Apple Pops                   0       1        1               0
# Charleston Chew                      1       0        0               0
# Chewey Lemonhead Fruit Mix           0       1        0               0
# Chiclets                             0       1        0               0
# Dots                                 0       1        0               0
# ...

# %%
df['winpercent'].hist()

# %%
df['winpercent'].describe()
# Out:
# count    85.000000
# mean     50.316764
# std      14.714357
# min      22.445341
# 25%      39.141056
# 50%      47.829754
# 75%      59.863998
# max      84.180290
# Name: winpercent, dtype: float64

# %%
sns.boxplot(data = df, orient = "h")

# %%
sns.boxplot(x = 'winpercent', y = 'competitorname', data = df)
