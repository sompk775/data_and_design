# %% [markdown]
# # Exploring Data
#
# **GOAL**:
#
# - Load and describe dataset, variables, and variable types
# - Explore categorical features and quantitative features using basic measures of center and spread (`.describe()`)
# - Filter categorical and quantitative features by logical criteria
# - Explore groups of categories using the `.groupby()` method.
# - Use `.nlargest()` and `.nsmallest()` to filter large and small values of interest

# %% [markdown]
# ## Load and Describe
#
# Below, we have a dataset from NYCOpenData related to police incidents.  First, we load in the dataset using the `pd.read_csv()` method.  Then, using the `.info()` method, we can examine the different features, feature data types, and missing values in the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style # LIGHTER
style.use('ggplot') or plt.style.use('ggplot')
# %matplotlib inline

# %%
police = pd.read_csv('data/nyc_police_incidents.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (12,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
# Unnamed: 0           100000 non-null int64
# addr_pct_cd          99999 non-null float64
# boro_nm              99997 non-null object
# cmplnt_fr_dt         99993 non-null object
# cmplnt_fr_tm         100000 non-null object
# cmplnt_num           100000 non-null int64
# cmplnt_to_dt         73252 non-null object
# cmplnt_to_tm         73272 non-null object
# crm_atpt_cptd_cd     100000 non-null object
# hadevelopt           2532 non-null object
# juris_desc           100000 non-null object
# ky_cd                100000 non-null int64
# lat_lon              11 non-null object
# latitude             11 non-null float64
# law_cat_cd           100000 non-null object
# loc_of_occur_desc    56034 non-null object
# longitude            11 non-null float64
# ofns_desc            99662 non-null object
# parks_nm             541 non-null object
# pd_cd                100000 non-null float64
# pd_desc              100000 non-null object
# prem_typ_desc        99506 non-null object
# rpt_dt               100000 non-null object
# x_coord_cd           11 non-null float64
# y_coord_cd           11 non-null float64
# dtypes: float64(6), int64(3), object(16)
# memory usage: 19.1+ MB

# %% [markdown]
# ### Split, Apply, Combine
#
# Using the `.groupby()` method is a great way to explore patterns within a categorical variable.  The effect of grouping our data based on boro name would allow us to then apply some kind of summary to the individual groups.  The image below demonstrate splitting and applying the mean to each group.  In our data, for example, if we wanted to know the number of complaints by borough, we could groupby the boro name and select a relevant column to count.
# ![](images/sac.png)

# %%
police.groupby('boro_nm')['cmplnt_fr_dt'].count()
# Out:
# boro_nm
# BRONX            22227
# BROOKLYN         20980
# MANHATTAN        20657
# QUEENS           31733
# STATEN ISLAND     4393
# Name: cmplnt_fr_dt, dtype: int64

# %% [markdown]
# If we wanted to plot the results, we can save the results as a variable and use a bar plot where we pull the names to be the horizontal values, and the count to be the height.  The names are the indicies of our variable; i.e. `bor.index()`.  The actual values are the only contents of `bor`.

# %%
bor = police.groupby('boro_nm')['cmplnt_fr_dt'].count()

# %%
bor
# Out:
# boro_nm
# BRONX            22227
# BROOKLYN         20980
# MANHATTAN        20657
# QUEENS           31733
# STATEN ISLAND     4393
# Name: cmplnt_fr_dt, dtype: int64

# %%
bor[0]
# Out:
# 22227

# %%
type(bor)
# Out:
# pandas.core.series.Series

# %%
bor.index
# Out:
# Index(['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND'], dtype='object', name='boro_nm')

# %%
bor[:]
# Out:
# boro_nm
# BRONX            22227
# BROOKLYN         20980
# MANHATTAN        20657
# QUEENS           31733
# STATEN ISLAND     4393
# Name: cmplnt_fr_dt, dtype: int64

# %%
plt.bar(bor.index, bor)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### Examining Wine Reviews
#
# ![](images/kwine.png)
#
# Below, we use a dataset on wine reviews from kaggle.com.  Again, we want to do some basic explorations of the data.  Here, we load in our zip file and examine the data.

# %%
wine = pd.read_csv('data/winemag-data-130k-v2.csv.zip', compression = 'zip')

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
# Unnamed: 0               129971 non-null int64
# country                  129908 non-null object
# description              129971 non-null object
# designation              92506 non-null object
# points                   129971 non-null int64
# price                    120975 non-null float64
# province                 129908 non-null object
# region_1                 108724 non-null object
# region_2                 50511 non-null object
# taster_name              103727 non-null object
# taster_twitter_handle    98758 non-null object
# title                    129971 non-null object
# variety                  129970 non-null object
# winery                   129971 non-null object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 13.9+ MB

# %% [markdown]
# Because we are dealing with wine ratings, we want to understand the good and bad.  Further, we may be interested in affordable good wines.  Accordingly, we would want to filter the price column to limit this boundary, and then find the highest reviewed wines.  For me, I will set the limit at 11 dollars.  Then, I want to see the best and worst wines and their information.

# %%
chuck = wine[wine['price'] < 11]

# %%
chuck.nlargest(5, 'points')
# Out:
#        Unnamed: 0   country  \
# 10386       10386        US
# 11955       11955  Portugal
# 18310       18310  Portugal
# 26101       26101        US
# 27415       27415        US
#
#                                              description         designation  \
# 10386  A marvelous effort in a difficult year, this t...                 NaN
# 11955  A firm wine, based on dry tannins and some den...       Mural Reserva
# 18310  Orange peel aromas emerge on this delectable f...                 NaN
# 26101  With full ripeness, density and concentration,...  Winemaker's Select
# 27415  Gorgeous aromas of peach, pear, flower and spi...                 NaN
#
#        points  price             province              region_1  \
# 10386      91    9.0           Washington  Columbia Valley (WA)
# 11955      91   10.0                Douro                   NaN
# 18310      91   10.0  Moscatel de Setúbal                   NaN
# 26101      91    8.0           Washington  Columbia Valley (WA)
# 27415      91   10.0           Washington  Columbia Valley (WA)
#
#               region_2   taster_name taster_twitter_handle  \
# 10386  Columbia Valley  Paul Gregutt           @paulgwine
# 11955              NaN    Roger Voss            @vossroger
# 18310              NaN    Roger Voss            @vossroger
# 26101  Columbia Valley  Paul Gregutt           @paulgwine
# 27415  Columbia Valley  Paul Gregutt           @paulgwine
#
#                                                    title         variety  \
# 10386  Chateau Ste. Michelle 2011 Riesling (Columbia ...        Riesling
# 11955    Quinta do Portal 2007 Mural Reserva Red (Douro)  Portuguese Red
# 18310    José Maria da Fonseca 2007  Moscatel de Setúbal        Moscatel
# 26101  Snoqualmie 2006 Winemaker's Select Riesling (C...        Riesling
# 27415  Barnard Griffin 2012 Riesling (Columbia Valley...        Riesling
#
#                       winery
# 10386  Chateau Ste. Michelle
# 11955       Quinta do Portal
# 18310  José Maria da Fonseca
# 26101             Snoqualmie
# 27415        Barnard Griffin

# %%
chuck.nsmallest(5, 'points')
# Out:
#        Unnamed: 0    country  \
# 3640         3640   Portugal
# 7333         7333         US
# 11085       11085     France
# 13782       13782      Chile
# 15609       15609  Argentina
#
#                                              description designation  points  \
# 3640   Aromas of strawberry sherbet are followed by s...     Estreia      80
# 7333   Too sweet by far for a table wine, with simple...         NaN      80
# 11085  A white this age should be fresh and crisp; th...         NaN      80
# 13782  Yeasty, melony and smelling like yellow mustar...  Left Coast      80
# 15609  Beware of funky labeled Malbecs because many d...         NaN      80
#
#        price          province    region_1          region_2  \
# 3640     8.0       Vinho Verde         NaN               NaN
# 7333    10.0        California  California  California Other
# 11085    8.0  Southwest France    Bergerac               NaN
# 13782    7.0             Chile         NaN               NaN
# 15609   10.0  Mendoza Province     Mendoza               NaN
#
#              taster_name taster_twitter_handle  \
# 3640          Roger Voss            @vossroger
# 7333                 NaN                   NaN
# 11085     Joe Czerwinski                @JoeCz
# 13782  Michael Schachner           @wineschach
# 15609  Michael Schachner           @wineschach
#
#                                              title      variety  \
# 3640     Viniverde 2011 Estreia Rosé (Vinho Verde)         Rosé
# 7333     Esser Cellars 2005 Zinfandel (California)    Zinfandel
# 11085  Seigneurs de Bergerac 1999 White (Bergerac)  White Blend
# 13782       flipflop NV Left Coast Moscato (Chile)      Moscato
# 15609               Ku Dé Ta 2006 Malbec (Mendoza)       Malbec
#
#                       winery
# 3640               Viniverde
# 7333           Esser Cellars
# 11085  Seigneurs de Bergerac
# 13782               flipflop
# 15609               Ku Dé Ta

# %% [markdown]
# If we wanted to see the largest producers of different varieties of wine, we could group by country, select the variety column, and apply a count on this.  To only see the five largest, we can then use the `.nlargest(5)` on the outcome of our split-apply-combine routine.

# %%
wine.groupby('country')['variety'].count().nlargest(5)
# Out:
# country
# US          54504
# France      22093
# Italy       19540
# Spain        6645
# Portugal     5691
# Name: variety, dtype: int64

# %%
wine['points'].hist()

# %%
wine['points'].describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
u18 = wine[wine['price'] <= 18]

# %%
u18.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
# 6           6     Italy  Here's a bright, informal red that opens with ...
#
#             designation  points  price           province  \
# 1              Avidagos      87   15.0              Douro
# 2                   NaN      87   14.0             Oregon
# 3  Reserve Late Harvest      87   13.0           Michigan
# 5          Ars In Vitro      87   15.0     Northern Spain
# 6               Belsito      87   16.0  Sicily & Sardinia
#
#               region_1           region_2         taster_name  \
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 5              Navarra                NaN   Michael Schachner
# 6             Vittoria                NaN       Kerin O’Keefe
#
#   taster_twitter_handle                                              title  \
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 5           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# 6          @kerinokeefe   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
#
#               variety               winery
# 1      Portuguese Red  Quinta dos Avidagos
# 2          Pinot Gris            Rainstorm
# 3            Riesling           St. Julian
# 5  Tempranillo-Merlot               Tandem
# 6            Frappato      Terre di Giurfo

# %%
u18.nlargest(10, 'points')
# Out:
#         Unnamed: 0   country  \
# 6267          6267        US
# 19136        19136     Spain
# 23974        23974  Portugal
# 39318        39318    France
# 69526        69526        US
# 84597        84597        US
# 88682        88682   Austria
# 98438        98438        US
# 123776      123776        US
# 3843          3843  Portugal
#
#                                               description  \
# 6267    This tastes like a more concentrated and sweet...
# 19136   A spectacularly sweet and rich bruiser, and on...
# 23974   Assobio is from a single vineyard in the Quint...
# 39318   A rich, sweet wine that maintains complete fre...
# 69526   This dry Moscato Giallo from Lodi is delicious...
# 84597   A gorgeous, rich and aromatic Riesling, this i...
# 88682   A little air is all that is needed to shake th...
# 98438   Vintner Carr follows up on his great 2008 Rese...
# 123776  Don't let the cartoony label fool you, this is...
# 3843    This is a smooth, impressively rich wine power...
#
#                                  designation  points  price          province  \
# 6267                    Lucille Late Harvest      94   18.0        Washington
# 19136        Pedro Ximenez 1827 Sweet Sherry      94   14.0         Andalucia
# 23974                                Assobio      94   13.0             Douro
# 39318                  Symphonie de Novembre      94   18.0  Southwest France
# 69526                                  Secco      94   16.0        California
# 84597                                 Estate      94   18.0            Oregon
# 88682                                Vm Berg      94   18.0           Kamptal
# 98438                            Dijon Clone      94   18.0        California
# 123776                          Petite Petit      94   18.0        California
# 3843    Aguia Moura em Vinhas Velhas Reserva      93   18.0             Douro
#
#                  region_1           region_2        taster_name  \
# 6267        Yakima Valley    Columbia Valley       Paul Gregutt
# 19136               Jerez                NaN  Michael Schachner
# 23974                 NaN                NaN         Roger Voss
# 39318            Jurançon                NaN         Roger Voss
# 69526                Lodi     Central Valley     Virginie Boone
# 84597   Willamette Valley  Willamette Valley       Paul Gregutt
# 88682                 NaN                NaN   Anne Krebiehl MW
# 98438        Sonoma Coast             Sonoma                NaN
# 123776               Lodi     Central Valley         Jim Gordon
# 3843                  NaN                NaN         Roger Voss
#
#        taster_twitter_handle  \
# 6267             @paulgwine
# 19136            @wineschach
# 23974             @vossroger
# 39318             @vossroger
# 69526                @vboone
# 84597            @paulgwine
# 88682            @AnneInVino
# 98438                    NaN
# 123776      @gordone_cellars
# 3843              @vossroger
#
#                                                     title         variety  \
# 6267    Stottle 2011 Lucille Late Harvest Viognier (Ya...        Viognier
# 19136   Osborne NV Pedro Ximenez 1827 Sweet Sherry She...          Sherry
# 23974          Quinta dos Murças 2011 Assobio Red (Douro)  Portuguese Red
# 39318   Domaine Cauhapé 2011 Symphonie de Novembre  (J...   Petit Manseng
# 69526            Uvaggio 2010 Secco Moscato Giallo (Lodi)  Moscato Giallo
# 84597   David Hill 2013 Estate Riesling (Willamette Va...        Riesling
# 88682           Eichinger 2014 Vm Berg Riesling (Kamptal)        Riesling
# 98438   Joseph Carr 2009 Dijon Clone Chardonnay (Sonom...      Chardonnay
# 123776  Michael David 2012 Petite Petit Petite Sirah (...    Petite Sirah
# 3843    Wines & Winemakers 2009 Aguia Moura em Vinhas ...  Portuguese Red
#
#                     winery
# 6267               Stottle
# 19136              Osborne
# 23974    Quinta dos Murças
# 39318      Domaine Cauhapé
# 69526              Uvaggio
# 84597           David Hill
# 88682            Eichinger
# 98438          Joseph Carr
# 123776       Michael David
# 3843    Wines & Winemakers

# %%
u18.nsmallest(10, 'points')
# Out:
#       Unnamed: 0    country  \
# 3640        3640   Portugal
# 3641        3641      Chile
# 4556        4556      Italy
# 4557        4557      Spain
# 5905        5905  Argentina
# 5907        5907  Argentina
# 5908        5908  Argentina
# 5909        5909  Argentina
# 7094        7094  Argentina
# 7095        7095  Argentina
#
#                                             description   designation  points  \
# 3640  Aromas of strawberry sherbet are followed by s...       Estreia      80
# 3641  Fluffy, sweet aromas of peach, pear and vanill...       Reserve      80
# 4556  There's a thorny, almost raw quality of fruit ...     Rondineto      80
# 4557  With dusty, candied aromas, the bouquet on thi...      Demi Sec      80
# 5905  Ashy, green and funky smelling, then sweet, ch...           NaN      80
# 5907  Heavily vegetal and unclean on the nose, then ...           NaN      80
# 5908  Mute on the nose, but heavy in the mouth, with...           NaN      80
# 5909  Medicinal and feral on the nose, then heavy, t...     Colección      80
# 7094  The only thing that makes this a gran reserva ...  Gran Reserva      80
# 7095  This is the first Torrontés from Pascual Toso ...           NaN      80
#
#       price          province        region_1 region_2        taster_name  \
# 3640    8.0       Vinho Verde             NaN      NaN         Roger Voss
# 3641   15.0      Maule Valley             NaN      NaN  Michael Schachner
# 4556   12.0     Central Italy  Colli Aprutini      NaN                NaN
# 4557   14.0         Catalonia            Cava      NaN  Michael Schachner
# 5905   17.0  Mendoza Province         Mendoza      NaN  Michael Schachner
# 5907   15.0  Mendoza Province         Mendoza      NaN  Michael Schachner
# 5908   12.0  Mendoza Province         Mendoza      NaN  Michael Schachner
# 5909   12.0  Mendoza Province         Mendoza      NaN  Michael Schachner
# 7094   18.0  Mendoza Province      Uco Valley      NaN  Michael Schachner
# 7095   12.0  Mendoza Province           Maipú      NaN  Michael Schachner
#
#      taster_twitter_handle                                              title  \
# 3640            @vossroger          Viniverde 2011 Estreia Rosé (Vinho Verde)
# 3641           @wineschach  Cuevas del Sur 2010 Reserve Chardonnay (Maule ...
# 4556                   NaN  Fattoria Giuseppe Savini 2011 Rondineto Merlot...
# 4557           @wineschach          Paul Cheneau NV Demi Sec Sparkling (Cava)
# 5905           @wineschach     Bodega Carmine Granata 2009 Sémillon (Mendoza)
# 5907           @wineschach             Ricardo Santos 2009 Sémillon (Mendoza)
# 5908           @wineschach                    Gardel 2009 Torrontés (Mendoza)
# 5909           @wineschach  Alma del Sur 2009 Colección Cabernet Sauvignon...
# 7094           @wineschach  Finca El Origen 2007 Gran Reserva Malbec (Uco ...
# 7095           @wineschach                Pascual Toso 2007 Torrontés (Maipú)
#
#                         variety                    winery
# 3640                       Rosé                 Viniverde
# 3641                 Chardonnay            Cuevas del Sur
# 4556                     Merlot  Fattoria Giuseppe Savini
# 4557            Sparkling Blend              Paul Cheneau
# 5905                   Sémillon    Bodega Carmine Granata
# 5907                   Sémillon            Ricardo Santos
# 5908                  Torrontés                    Gardel
# 5909  Cabernet Sauvignon-Malbec              Alma del Sur
# 7094                     Malbec           Finca El Origen
# 7095                  Torrontés              Pascual Toso

# %%
wine.groupby('taster_name')['points'].mean().sort_values(ascending = False).plot(kind = 'bar', figsize = (9, 5), title = 'Tasters Scores', color = 'green')
style.use('seaborn-dark')
plt.ylim(80, 95)
# Out:
# (80, 95)

# %% [markdown]
# ### PROBLEMS
#
# 1. What is the top rated red wine under eighteen dollars a bottle?  Lowest rated white in the same price range?
# There are a few top rated red wines under $18. These include: Osborne NV Pedro Ximenez 1827 Sweet Sherry, Quinta dos Murças 2011 Assobio Red, Michael David 2012 Petite Petit Petite Sirah, and Wines & Winemakers 2009 Aguia Moura em Vinhas. The lowest rated white in the same price range include: Cuevas del Sur 2010 Reserve Chardonnay, Paul Cheneau NV Demi Sec Sparkling (possibly... it's a sparkling blend), Bodega Carmine Granata 2009 Sémillon, Ricardo Santos 2009 Sémillon, Gardel 2009 Torrontés, and Pascual Toso 2007 Torrontés.
#
# 2. What reviewers were the most generous?  The least?  Describe your approach.
# Based on the ascending bar graph, the most generous reviewer was Anne Krebiehl MW while the least generous was Alexander Peatree. Anne Krebiehl MW had an average of 91 points while Alexander Peatree had an average of nearly 86 points.
#
# 3. Suppose we have the following data read in as a pandas dataframe called `df`.
#
# | id | name | age | speed | color |
# |  ----- | ----- | ----- | ----- | ----- |
# | 1 | Hennessy | 12 | 4.2 | red |
# | 2 | Tino | 5 | 6.9 | white |
# | 3 | Oden | 11 | 5.5 | yellow |
# | 4 | LuLu | 6  | 4.5 | red |
#
# Write the result of the following operations
#
# - `df['name']` = all the data from the name column
# - `df['color'].value_counts()` = the number count of each color
# - `df.nlargest(2, 'age')` = the two oldest people
# - `df.describe()` = min, max, mean, Q1, Q3
# - `df.groupby('color')['age'].mean()` = average ages per color
#
#
# 4. Go back to the wine data.  Write down five purely descriptive questions that could be answered from the data.
#     1. Which country has the highest ranking wine (avg)?
#     2. Which province has the highest ranking wine (avg)?
#     3. Who makes the most wine?
#     4. What type of wine receives higher ratings?
#     5. Which country produces the most wine?
# 5. Choose three of your questions and provide an initial answer.  If you run into problems please post in slack.
# The country that produces the most wine is America. The province which has the highest ranking wine (in terms of averages) is Südburgenland, Austria. The country which has the highest ranking wine (in terms of averages) is England.
#
# 6. Find a tutorial online dealing with Pandas.  One place to look is the Pandas documentation (https://pandas.pydata.org/pandas-docs/stable/tutorials.html).  Go through the tutorial and write a few sentences describing the topic, what you learned, and what you are still confused about in terms of operations with Pandas.  There are many youtube tutorials, blogs, and open source texts that detail python and pandas, find something you're interested in, you will be sharing this with the class.

# %%
wine.groupby('country').count()
# Out:
#                         Unnamed: 0  description  designation  points  price  \
# country
# Argentina                     3800         3800         2902    3800   3756
# Armenia                          2            2            2       2      2
# Australia                     2329         2329         1640    2329   2294
# Austria                       3345         3345         2825    3345   2799
# Bosnia and Herzegovina           2            2            1       2      2
# Brazil                          52           52           51      52     47
# Bulgaria                       141          141           93     141    141
# Canada                         257          257          179     257    254
# Chile                         4472         4472         3879    4472   4416
# China                            1            1            1       1      1
# Croatia                         73           73           48      73     71
# Cyprus                          11           11            9      11     11
# Czech Republic                  12           12            7      12     12
# Egypt                            1            1            1       1      0
# England                         74           74           74      74     69
# France                       22093        22093        14530   22093  17776
# Georgia                         86           86           62      86     84
# Germany                       2165         2165         2006    2165   2120
# Greece                         466          466          319     466    461
# Hungary                        146          146          124     146    145
# India                            9            9            4       9      9
# Israel                         505          505          435     505    489
# Italy                        19540        19540        13889   19540  16914
# Lebanon                         35           35           30      35     35
# Luxembourg                       6            6            6       6      6
# Macedonia                       12           12            5      12     12
# Mexico                          70           70           53      70     70
# Moldova                         59           59           52      59     59
# Morocco                         28           28           16      28     28
# New Zealand                   1419         1419          684    1419   1378
# Peru                            16           16           16      16     16
# Portugal                      5691         5691         5105    5691   4875
# Romania                        120          120          114     120    120
# Serbia                          12           12            9      12     12
# Slovakia                         1            1            0       1      1
# Slovenia                        87           87           60      87     80
# South Africa                  1401         1401          822    1401   1293
# Spain                         6645         6645         5320    6645   6573
# Switzerland                      7            7            3       7      7
# Turkey                          90           90           63      90     90
# US                           54504        54504        36908   54504  54265
# Ukraine                         14           14           12      14     14
# Uruguay                        109          109           95     109    109
#
#                         province  region_1  region_2  taster_name  \
# country
# Argentina                   3800      3747         0         3797
# Armenia                        2         0         0            2
# Australia                   2329      2327         0         2037
# Austria                     3345         0         0         3337
# Bosnia and Herzegovina         2         0         0            2
# Brazil                        52         0         0           52
# Bulgaria                     141         0         0          141
# Canada                       257       257         0          256
# Chile                       4472         0         0         4361
# China                          1         0         0            1
# Croatia                       73         0         0           73
# Cyprus                        11         0         0           11
# Czech Republic                12         0         0           12
# Egypt                          1         0         0            1
# England                       74         0         0           74
# France                     22093     22017         0        21828
# Georgia                       86         0         0           86
# Germany                     2165         0         0         2134
# Greece                       466         0         0          466
# Hungary                      146         0         0          145
# India                          9         0         0            9
# Israel                       505         0         0          500
# Italy                      19540     19513         0        11042
# Lebanon                       35         0         0           35
# Luxembourg                     6         0         0            6
# Macedonia                     12         0         0           12
# Mexico                        70         0         0           65
# Moldova                       59         0         0           59
# Morocco                       28         0         0           28
# New Zealand                 1419         0         0         1311
# Peru                          16         0         0           16
# Portugal                    5691         0         0         5686
# Romania                      120         0         0          120
# Serbia                        12         0         0           12
# Slovakia                       1         0         0            1
# Slovenia                      87         0         0           87
# South Africa                1401         0         0         1328
# Spain                       6645      6637         0         6581
# Switzerland                    7         0         0            7
# Turkey                        90         0         0           90
# US                         54504     54226     50511        37730
# Ukraine                       14         0         0           14
# Uruguay                      109         0         0          109
#
#                         taster_twitter_handle  title  variety  winery
# country
# Argentina                                3797   3800     3800    3800
# Armenia                                     2      2        2       2
# Australia                                2037   2329     2329    2329
# Austria                                  3337   3345     3345    3345
# Bosnia and Herzegovina                      1      2        2       2
# Brazil                                     52     52       52      52
# Bulgaria                                  122    141      141     141
# Canada                                    241    257      257     257
# Chile                                    4361   4472     4471    4472
# China                                       1      1        1       1
# Croatia                                    34     73       73      73
# Cyprus                                     11     11       11      11
# Czech Republic                              8     12       12      12
# Egypt                                       1      1        1       1
# England                                    74     74       74      74
# France                                  21828  22093    22093   22093
# Georgia                                    64     86       86      86
# Germany                                   375   2165     2165    2165
# Greece                                    466    466      466     466
# Hungary                                   113    146      146     146
# India                                       9      9        9       9
# Israel                                    500    505      505     505
# Italy                                   11042  19540    19540   19540
# Lebanon                                    25     35       35      35
# Luxembourg                                  6      6        6       6
# Macedonia                                  11     12       12      12
# Mexico                                     65     70       70      70
# Moldova                                    58     59       59      59
# Morocco                                    26     28       28      28
# New Zealand                              1311   1419     1419    1419
# Peru                                       16     16       16      16
# Portugal                                 5686   5691     5691    5691
# Romania                                    79    120      120     120
# Serbia                                     12     12       12      12
# Slovakia                                    0      1        1       1
# Slovenia                                   61     87       87      87
# South Africa                             1328   1401     1401    1401
# Spain                                    6581   6645     6645    6645
# Switzerland                                 7      7        7       7
# Turkey                                     85     90       90      90
# US                                      34741  54504    54504   54504
# Ukraine                                    12     14       14      14
# Uruguay                                   109    109      109     109

# %%
wine.groupby('province')['points'].mean().sort_values(ascending = False).plot(kind = 'bar', figsize = (50, 15), title = 'Province Ratings', color = 'pink')
style.use('bmh')
plt.ylim(80, 100)
# Out:
# (80, 100)

# %%
wine.groupby('country')['points'].mean().sort_values(ascending = False).plot(kind = 'bar', figsize = (20, 15), title = 'Province Ratings', color = 'orange')
style.use('seaborn-dark-palette')
plt.ylim(80, 100)
# Out:
# (80, 100)
